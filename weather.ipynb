# %% [markdown]
# <a href="https://colab.research.google.com/github/ohirshman/Data-science-projects/blob/main/weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile app.py
%pip install streamlit
import streamlit as st

st.title("My First Streamlit App in Colab")

st.write("Hello, world! This app is running from Google Colab. 👋")

st.header("Interactive Widget")
x = st.slider("Select a value", 0, 100, 25)
st.write(f"You selected the value: {x}")
# Out:
# Writing app.py
